# %%
import pandas as pd
import numpy as np
import IPython.display as display
import matplotlib.pyplot as plt
import seaborn as sns
from  matplotlib.ticker import PercentFormatter, ScalarFormatter

# %%
df = pd.read_csv('elden_ring_weapon.csv')

# %%
print(df.head(3))
# Out:
#                        Name              Type  Phy Mag Fir Lit Hol  Cri  Sta  \
# 0  Academy Glintstone Staff  Glintstone Staff   43   -   -   -   -  100   40
# 1    Alabaster Lord's Sword        Greatsword  313  93   -   -   -  100  126
# 2            Albinauric Bow               Bow  200   -   -   -   -  100   60
#
#   Str  ... Any Phy.1 Mag.1 Fir.1 Lit.1 Hol.1 Bst Rst  Wgt  \
# 0   D  ...   -    25    15    15    15    15  15  10  3.0
# 1   B  ...   -    56    33    27    27    27  39  19  8.0
# 2   E  ...   -     -     -     -     -     -   -   -  4.5
#
#                   Upgrade
# 0         Smithing Stones
# 1  Somber Smithing Stones
# 2         Smithing Stones
#
# [3 rows x 24 columns]

# %%
print(df.info())
cols = df.columns
print(cols)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 24 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     307 non-null    object
#  1   Type     307 non-null    object
#  2   Phy      307 non-null    object
#  3   Mag      307 non-null    object
#  4   Fir      307 non-null    object
#  5   Lit      307 non-null    object
#  6   Hol      307 non-null    object
#  7   Cri      307 non-null    int64
#  8   Sta      307 non-null    int64
#  9   Str      307 non-null    object
#  10  Dex      307 non-null    object
#  11  Int      307 non-null    object
#  12  Fai      307 non-null    object
#  13  Arc      307 non-null    object
#  14  Any      307 non-null    object
#  15  Phy.1    307 non-null    object
#  16  Mag.1    307 non-null    object
#  17  Fir.1    307 non-null    object
#  18  Lit.1    307 non-null    object
#  19  Hol.1    307 non-null    object
#  20  Bst      307 non-null    object
#  21  Rst      307 non-null    object
#  22  Wgt      307 non-null    float64
#  23  Upgrade  307 non-null    object
# dtypes: float64(1), int64(2), object(21)
# memory usage: 57.7+ KB
# None
# Index(['Name', 'Type', 'Phy', 'Mag', 'Fir', 'Lit', 'Hol', 'Cri', 'Sta', 'Str',
#        'Dex', 'Int', 'Fai', 'Arc', 'Any', 'Phy.1', 'Mag.1', 'Fir.1', 'Lit.1',
#        'Hol.1', 'Bst', 'Rst', 'Wgt', 'Upgrade'],
#       dtype='object')

# %%
da = df.loc[:,:]
print(da)
# Out:
#                          Name               Type  Phy  Mag Fir Lit  Hol  Cri  \
# 0    Academy Glintstone Staff   Glintstone Staff   43    -   -   -    -  100
# 1      Alabaster Lord's Sword         Greatsword  313   93   -   -    -  100
# 2              Albinauric Bow                Bow  200    -   -   -    -  100
# 3            Albinauric Staff   Glintstone Staff   29    -   -   -    -  100
# 4              Antspur Rapier    Thrusting Sword  240    -   -   -    -  100
# ..                        ...                ...  ...  ...  ..  ..  ...  ...
# 302             Wing of Astel       Curved Sword  159  191   -   -    -  100
# 303          Winged Greathorn           Greataxe  318    -   -   -    -  100
# 304             Winged Scythe             Reaper  213    -   -   -  254  100
# 305        Zamor Curved Sword  Curved Greatsword  306    -   -   -    -  100
# 306                Zweihander     Colossal Sword  345    -   -   -    -  100
#
#      Sta Str  ...   Any Phy.1 Mag.1 Fir.1 Lit.1 Hol.1 Bst Rst   Wgt  \
# 0     40   D  ...     -    25    15    15    15    15  15  10   3.0
# 1    126   B  ...     -    56    33    27    27    27  39  19   8.0
# 2     60   E  ...     -     -     -     -     -     -   -   -   4.5
# 3     38   D  ...     -    23    14    14    14    14  14   9   2.5
# 4     62   D  ...  (55)    47    31    31    31    31  25  10   3.0
# ..   ...  ..  ...   ...   ...   ...   ...   ...   ...  ..  ..   ...
# 302   84   E  ...     -    28    52    23    23    23  23   9   2.5
# 303  150   C  ...     -    65    35    35    35    35  42  20  11.0
# 304  110   D  ...  (55)    30    25    25    25    55  30  15   7.5
# 305  128   C  ...  (65)    61    33    33    33    33  39  19   9.0
# 306  126   D  ...     -    67    40    40    40    40  54  22  15.5
#
#                     Upgrade
# 0           Smithing Stones
# 1    Somber Smithing Stones
# 2           Smithing Stones
# 3           Smithing Stones
# 4           Smithing Stones
# ..                      ...
# 302  Somber Smithing Stones
# 303  Somber Smithing Stones
# 304  Somber Smithing Stones
# 305  Somber Smithing Stones
# 306         Smithing Stones
#
# [307 rows x 24 columns]

# %%
print(da)
# Out:
#                          Name               Type  Phy  Mag Fir Lit  Hol  Cri  \
# 0    Academy Glintstone Staff   Glintstone Staff   43    0   0   0    0  100
# 1      Alabaster Lord's Sword         Greatsword  313   93   0   0    0  100
# 2              Albinauric Bow                Bow  200    0   0   0    0  100
# 3            Albinauric Staff   Glintstone Staff   29    0   0   0    0  100
# 4              Antspur Rapier    Thrusting Sword  240    0   0   0    0  100
# ..                        ...                ...  ...  ...  ..  ..  ...  ...
# 302             Wing of Astel       Curved Sword  159  191   0   0    0  100
# 303          Winged Greathorn           Greataxe  318    0   0   0    0  100
# 304             Winged Scythe             Reaper  213    0   0   0  254  100
# 305        Zamor Curved Sword  Curved Greatsword  306    0   0   0    0  100
# 306                Zweihander     Colossal Sword  345    0   0   0    0  100
#
#      Sta Str  ...   Any Phy.1 Mag.1 Fir.1 Lit.1 Hol.1 Bst Rst   Wgt  \
# 0     40   D  ...     -    25    15    15    15    15  15  10   3.0
# 1    126   B  ...     -    56    33    27    27    27  39  19   8.0
# 2     60   E  ...     -     0     0     0     0     0   0   0   4.5
# 3     38   D  ...     -    23    14    14    14    14  14   9   2.5
# 4     62   D  ...  (55)    47    31    31    31    31  25  10   3.0
# ..   ...  ..  ...   ...   ...   ...   ...   ...   ...  ..  ..   ...
# 302   84   E  ...     -    28    52    23    23    23  23   9   2.5
# 303  150   C  ...     -    65    35    35    35    35  42  20  11.0
# 304  110   D  ...  (55)    30    25    25    25    55  30  15   7.5
# 305  128   C  ...  (65)    61    33    33    33    33  39  19   9.0
# 306  126   D  ...     -    67    40    40    40    40  54  22  15.5
#
#                     Upgrade
# 0           Smithing Stones
# 1    Somber Smithing Stones
# 2           Smithing Stones
# 3           Smithing Stones
# 4           Smithing Stones
# ..                      ...
# 302  Somber Smithing Stones
# 303  Somber Smithing Stones
# 304  Somber Smithing Stones
# 305  Somber Smithing Stones
# 306         Smithing Stones
#
# [307 rows x 24 columns]

# %%
# for colu in da.columns[2:9]:
#     da[colu] = da[colu].str.replace(r'-','0', regex=True).to_list()
# for colu in da.columns[15:23]:
#     da[colu] = da[colu].str.replace(r'-','0', regex=True).to_list()
# da[colu] = da[colu].astype('str').astype('int')
# print(da.info())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\huytr\OneDrive\Programming\Python\Elder_Ring\elden_ring_weapon\Elden_Ring.ipynb Cell 7' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/elden_ring_weapon/Elden_Ring.ipynb#ch0000006?line=0'>1</a> # for colu in da.columns[2:9]:
#       <a href='vscode-notebook-cell:/c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/elden_ring_weapon/Elden_Ring.ipynb#ch0000006?line=1'>2</a> #     da[colu] = da[colu].str.replace(r'-','0', regex=True).to_list()
#       <a href='vscode-notebook-cell:/c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/elden_ring_weapon/Elden_Ring.ipynb#ch0000006?line=2'>3</a> for colu in da.columns[15:23]:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/elden_ring_weapon/Elden_Ring.ipynb#ch0000006?line=3'>4</a>     da[colu] = da[colu].str.replace(r'-','0', regex=True).to_list()
#
# File c:\Users\huytr\OneDrive\Programming\Python\Elder_Ring\Winenv\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5567'>5568</a> if (
#    <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5568'>5569</a>     name not in self._internal_names_set
#    <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5569'>5570</a>     and name not in self._metadata
#    <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5570'>5571</a>     and name not in self._accessors
#    <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5571'>5572</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5572'>5573</a> ):
#    <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5573'>5574</a>     return self[name]
# -> <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/generic.py?line=5574'>5575</a> return object.__getattribute__(self, name)
#
# File c:\Users\huytr\OneDrive\Programming\Python\Elder_Ring\Winenv\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=178'>179</a> if obj is None:
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=179'>180</a>     # we're accessing the attribute of the class, i.e., Dataset.geo
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=180'>181</a>     return self._accessor
# --> <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=181'>182</a> accessor_obj = self._accessor(obj)
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=182'>183</a> # Replace the property with the accessor object. Inspired by:
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=183'>184</a> # https://www.pydanny.com/cached-property.html
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=184'>185</a> # We need to use object.__setattr__ because we overwrite __setattr__ on
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=185'>186</a> # NDFrame
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/accessor.py?line=186'>187</a> object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\huytr\OneDrive\Programming\Python\Elder_Ring\Winenv\lib\site-packages\pandas\core\strings\accessor.py:177, in StringMethods.__init__(self, data)
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=173'>174</a> def __init__(self, data):
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=174'>175</a>     from pandas.core.arrays.string_ import StringDtype
# --> <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=176'>177</a>     self._inferred_dtype = self._validate(data)
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=177'>178</a>     self._is_categorical = is_categorical_dtype(data.dtype)
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=178'>179</a>     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\huytr\OneDrive\Programming\Python\Elder_Ring\Winenv\lib\site-packages\pandas\core\strings\accessor.py:231, in StringMethods._validate(data)
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=227'>228</a> inferred_dtype = lib.infer_dtype(values, skipna=True)
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=229'>230</a> if inferred_dtype not in allowed_types:
# --> <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=230'>231</a>     raise AttributeError("Can only use .str accessor with string values!")
#     <a href='file:///c%3A/Users/huytr/OneDrive/Programming/Python/Elder_Ring/Winenv/lib/site-packages/pandas/core/strings/accessor.py?line=231'>232</a> return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
# Plot Weapon Types
fig,ax = plt.subplots(figsize = (25,10))
plt.title("Weapon Types",size = 22,weight = 'bold')

sns.barplot(data = da['Type'].value_counts().reset_index(),x = 'Type',y='index')
sns.set_style("whitegrid")
plt.ylabel("Weapon Type", size = 16, weight="bold")
plt.xlabel("")
plt.xticks([])
plt.yticks(size=16)
plt.tick_params(size=16)

# %%
#Plot Weapon Weight
fig,ax = plt.subplots(figsize=(25,10))
plt.title("Weapon Weights", size =20,weight = "bold")

sns.histplot(data = da,x = "Wgt",binwidth =1,stat='probability',ec='black',lw=1,ax=ax)
sns.set_style('whitegrid')

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.yaxis.set_major_formatter(PercentFormatter(1))

# %%
df[df['Wgt'] == df['Wgt'].min()]
# Out:
#                       Name         Type Phy Mag Fir Lit  Hol  Cri  Sta Str  \
# 45             Cipher Pata         Fist   0   0   0   0  208  100   90   -
# 74   Dragon Communion Seal  Sacred Seal  61   0   0   0    0  100   40   -
# 88            Erdtree Seal  Sacred Seal  61   0   0   0   36  100   40   -
# 100    Frenzied Flame Seal  Sacred Seal  61   0   0   0    0  100   40   C
# 127      Golden Order Seal  Sacred Seal  58   0   0   0    0  100   40   -
#
#      ...   Any Phy.1 Mag.1 Fir.1 Lit.1 Hol.1 Bst Rst  Wgt  \
# 45   ...     -     9    14    14    14    61  19   9  0.0
# 74   ...     -    25    15    15    15    15  15  10  0.0
# 88   ...     -    25    15    15    15    15  15  10  0.0
# 100  ...  (55)    25    15    15    15    15  15  10  0.0
# 127  ...     -    25    15    15    15    15  15  10  0.0
#
#                     Upgrade
# 45   Somber Smithing Stones
# 74   Somber Smithing Stones
# 88   Somber Smithing Stones
# 100  Somber Smithing Stones
# 127  Somber Smithing Stones
#
# [5 rows x 24 columns]

# %%
#Plot Weapon Phys
fig,ax = plt.subplots(figsize=(40,10))
plt.title("Weapon (Phys dmg)", size =20,weight = "bold")

sns.histplot(data = WeaPhy,x = "Phy",binwidth = 1000)
sns.set_style('white')

plt.ylabel("Count",size=12,weight="bold")
plt.xlabel("Physical Def",size =12,weight="bold")
plt.yticks(size =16)
plt.tick_params(size =16)

# %%
df[df['Phy']==df['Phy'].max()]
# Out:
#            Name Type Phy Mag Fir Lit  Hol  Cri  Sta Str  ... Any Phy.1 Mag.1  \
# 86  Erdtree Bow  Bow  98   0   0   0  122  100   60   E  ...   -     0     0
#
#    Fir.1 Lit.1 Hol.1 Bst Rst  Wgt                 Upgrade
# 86     0     0     0   0   0  4.0  Somber Smithing Stones
#
# [1 rows x 24 columns]

# %%
# Add-on
def show_values_on_bars(axs, h_v="v", space=0.4):
    '''Plots the value at the end of the a seaborn barplot.
    axs: the ax of the plot
    h_v: weather or not the barplot is vertical/ horizontal'''
    
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, format(value, ','), ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, format(value, ','), ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)
