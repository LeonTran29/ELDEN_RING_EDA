# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

df = pd.read_csv('elden_ring_weapon.csv')

df.columns = df.columns.str.replace('.1','_Guard')
# Out:
# C:\Users\huytr\AppData\Local\Temp\ipykernel_348\1199080171.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('.1','_Guard')

# %%
for col in df.columns:
    df[col].replace({'-':np.nan},inplace=True)

# %%
# Plot Weapon Types
fig,ax = plt.subplots(figsize = (25,10))
plt.title("Weapon Types",size = 22,weight = 'bold')

sns.barplot(data = df['Type'].value_counts().reset_index(),x = 'Type',y='index')
sns.set_style("whitegrid")
plt.ylabel("Weapon Type", size = 16, weight="bold")
plt.xlabel("")
plt.xticks([])
plt.yticks(size=16)
plt.tick_params(size=16)

# %%
da = df.iloc[:,:]
display(da)
# Out:
#                          Name               Type  Phy  Mag  Fir  Lit  Hol  \
# 0    Academy Glintstone Staff   Glintstone Staff   43  NaN  NaN  NaN  NaN
# 1      Alabaster Lord's Sword         Greatsword  313   93  NaN  NaN  NaN
# 2              Albinauric Bow                Bow  200  NaN  NaN  NaN  NaN
# 3            Albinauric Staff   Glintstone Staff   29  NaN  NaN  NaN  NaN
# 4              Antspur Rapier    Thrusting Sword  240  NaN  NaN  NaN  NaN
# ..                        ...                ...  ...  ...  ...  ...  ...
# 302             Wing of Astel       Curved Sword  159  191  NaN  NaN  NaN
# 303          Winged Greathorn           Greataxe  318  NaN  NaN  NaN  NaN
# 304             Winged Scythe             Reaper  213  NaN  NaN  NaN  254
# 305        Zamor Curved Sword  Curved Greatsword  306  NaN  NaN  NaN  NaN
# 306                Zweihander     Colossal Sword  345  NaN  NaN  NaN  NaN
#
#      Cri  Sta Str  ...   Any Phy_Guard Mag_Guard Fir_Guard Lit_Guard  \
# 0    100   40   D  ...   NaN        25        15        15        15
# 1    100  126   B  ...   NaN        56        33        27        27
# 2    100   60   E  ...   NaN       NaN       NaN       NaN       NaN
# 3    100   38   D  ...   NaN        23        14        14        14
# 4    100   62   D  ...  (55)        47        31        31        31
# ..   ...  ...  ..  ...   ...       ...       ...       ...       ...
# 302  100   84   E  ...   NaN        28        52        23        23
# 303  100  150   C  ...   NaN        65        35        35        35
# 304  100  110   D  ...  (55)        30        25        25        25
# 305  100  128   C  ...  (65)        61        33        33        33
# 306  100  126   D  ...   NaN        67        40        40        40
#
#     Hol_Guard  Bst  Rst   Wgt                 Upgrade
# 0          15   15   10   3.0         Smithing Stones
# 1          27   39   19   8.0  Somber Smithing Stones
# 2         NaN  NaN  NaN   4.5         Smithing Stones
# 3          14   14    9   2.5         Smithing Stones
# 4          31   25   10   3.0         Smithing Stones
# ..        ...  ...  ...   ...                     ...
# 302        23   23    9   2.5  Somber Smithing Stones
# 303        35   42   20  11.0  Somber Smithing Stones
# 304        55   30   15   7.5  Somber Smithing Stones
# 305        33   39   19   9.0  Somber Smithing Stones
# 306        40   54   22  15.5         Smithing Stones
#
# [307 rows x 24 columns]

# %%
melee_wea = ['Axe','Claw','Colossal Sword','Curved Greatsword','Curved Sword','Dagger','Fist','Greatsword','Great Spear','Greataxe','Halberd','Hammer','Heavy Thrusting Sword','Katana','Reaper','Twinblade','Warhammer','Whip','Colossal Weapon','Flail','Spear','Straight Sword','Thrusting Sword']
range_wea = ['Ballista','Bow','Crossbow','Greatbow','Light Bow',]
magic_wea = ['Glintstone Staff','Sacred Seal']
da['category'] = ["Melee" if ele in melee_wea else "Range" if ele in range_wea else "Magic" if ele in magic_wea else "None" for ele in da['Type']]
display(da)
# Out:
#                          Name               Type  Phy  Mag  Fir  Lit  Hol  \
# 0    Academy Glintstone Staff   Glintstone Staff   43  NaN  NaN  NaN  NaN
# 1      Alabaster Lord's Sword         Greatsword  313   93  NaN  NaN  NaN
# 2              Albinauric Bow                Bow  200  NaN  NaN  NaN  NaN
# 3            Albinauric Staff   Glintstone Staff   29  NaN  NaN  NaN  NaN
# 4              Antspur Rapier    Thrusting Sword  240  NaN  NaN  NaN  NaN
# ..                        ...                ...  ...  ...  ...  ...  ...
# 302             Wing of Astel       Curved Sword  159  191  NaN  NaN  NaN
# 303          Winged Greathorn           Greataxe  318  NaN  NaN  NaN  NaN
# 304             Winged Scythe             Reaper  213  NaN  NaN  NaN  254
# 305        Zamor Curved Sword  Curved Greatsword  306  NaN  NaN  NaN  NaN
# 306                Zweihander     Colossal Sword  345  NaN  NaN  NaN  NaN
#
#      Cri  Sta Str  ... Phy_Guard Mag_Guard Fir_Guard Lit_Guard Hol_Guard  Bst  \
# 0    100   40   D  ...        25        15        15        15        15   15
# 1    100  126   B  ...        56        33        27        27        27   39
# 2    100   60   E  ...       NaN       NaN       NaN       NaN       NaN  NaN
# 3    100   38   D  ...        23        14        14        14        14   14
# 4    100   62   D  ...        47        31        31        31        31   25
# ..   ...  ...  ..  ...       ...       ...       ...       ...       ...  ...
# 302  100   84   E  ...        28        52        23        23        23   23
# 303  100  150   C  ...        65        35        35        35        35   42
# 304  100  110   D  ...        30        25        25        25        55   30
# 305  100  128   C  ...        61        33        33        33        33   39
# 306  100  126   D  ...        67        40        40        40        40   54
#
#      Rst   Wgt                 Upgrade category
# 0     10   3.0         Smithing Stones    Magic
# 1     19   8.0  Somber Smithing Stones    Melee
# 2    NaN   4.5         Smithing Stones    Range
# 3      9   2.5         Smithing Stones    Magic
# 4     10   3.0         Smithing Stones    Melee
# ..   ...   ...                     ...      ...
# 302    9   2.5  Somber Smithing Stones    Melee
# 303   20  11.0  Somber Smithing Stones    Melee
# 304   15   7.5  Somber Smithing Stones    Melee
# 305   19   9.0  Somber Smithing Stones    Melee
# 306   22  15.5         Smithing Stones    Melee
#
# [307 rows x 25 columns]

# %%
def show_values_on_bars(axs, h_v="v", space=0.4):
    '''Plots the value at the end of the a seaborn barplot.
    axs: the ax of the plot
    h_v: weather or not the barplot is vertical/ horizontal'''
    
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, format(value, ','), ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, format(value, ','), ha="left",fontsize = 20)

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)
        
fig,ax = plt.subplots(figsize = (25,15))
plt.title("Weapon Category",size = 22,weight = 'bold')

sns.barplot(data = df['category'].value_counts().reset_index(),x = 'category',y='index')
sns.set_style("whitegrid")
plt.ylabel("Weapon category", size = 16, weight="bold")
plt.xlabel("")
plt.xticks([])
plt.yticks(size=16)
plt.tick_params(size=16)
show_values_on_bars(axs=ax,h_v='h',space = 0.5)
